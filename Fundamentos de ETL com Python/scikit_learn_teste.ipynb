# %% [markdown]
# <a href="https://colab.research.google.com/github/maraisi/dio.repo/blob/main/Fundamentos%20de%20ETL%20com%20Python/scikit_learn_teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fundamentos de ETL com Python**

# %%
from sklearn.datasets import make_regression
#gerando uma massa de dados
x, y = make_regression(n_samples=200, n_features=1,noise=30)

# %%
import matplotlib.pyplot as plt

#mostrando o gráfico
plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
#criação do modelo
modelo = LinearRegression()

# %%
plt.scatter(x,y)
modelo.fit(x,y) #faltou o fit
plt.plot(x, modelo.predict(x), color='red', linewidth=2)
plt.show()
